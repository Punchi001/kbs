# %%
from itertools import count


general_problem=['Heavy menses','liver problem','Blood Pressure','cancer']
preference=['baby','hormonal']
disease_prevention=['STD & HIV']
answer=[]
IUD=['copper_allergy','STD & HIV','non_hormonal','baby']
P2=['Blood Pressure','Heavy menses','hormonal','baby','STD & HIV']
pill=['hormonal','baby','liver problem','cancer','Heavy menses','STD & HIV']
pull_out=['non_hormonal','STD & HIV']
condom=['non_hormonal']

adv_iud =['"IUD" stands for "intrauterine device." Shaped like a "T" and a bit bigger than a quarter, an IUD fits inside your uterus. It prevents pregnancy by stopping sperm from reaching and fertilizing eggs.']
adv_p2=['Levonorgestrel is used by women to prevent pregnancy after birth control failure (such as a broken condom) or unprotected sex. This medication is an emergency contraceptive and should not be used as a regular form of birth control.Using this medication will not stop an existing pregnancy or protect you or your partner against sexually transmitted diseases (such as HIV, gonorrhea, chlamydia).']
adv_pill=['The Pill is  a tablet taken once a day.Combined pill has estrogen and progestin ,which stops ovaries from releasing eggs.Mini pill contains only one hormone,progestin which is an alternative to those affected by the hormone estrogen.You should swallow the pill at the same time daily,whether or not you have sex.']
adv_pull_out=['Pulling out requires no additional hormone or devices,just timing and a lot of luck.It requires greta self-control,experience and trust and as such pretty unreliable.Work some of the time,by the man taking his penis out of vagina before he ejaculates,limiting chances of sperm reaching the egg.']
adv_condom=['A condom is a thin sheath,for the male ,its paced over a mans erect before having sex whereas for the female its inserted in the vaginaRegardless who is wearing,the re is lubricated thin polyurethane sheath that creates a barrier between where the sperms comes from and where it wants to go.Condoms come in all shapes,sizes and for senstive materials so evem with allergies or senstive skin,theres a condom to suit you comforatbly.']

print('Type yes(y) or no (n) from the following set of questions:')

for i in general_problem:
    x=input(f"[do you have  {i} ]")
    if x=='yes' or x=='y':
        answer.append(i)

    elif x=='no' or x=='n':
        pass
for i in preference:
    
    x=(input(f"[Would you wish to have a {i} ]"))
    if x=='yes' or x=='y':
        answer.append(i)

    elif x==0:
        pass
for i in disease_prevention:
    
    x=(input(f"[Would you want to be protected from  {i}  infection]"))
    if x=='yes' or x=='y':
        answer.append(i)

    elif x==0:
        pass
print(answer)
a=[]
b=[]
c=[]
d=[]
e=[]
for i in answer:
    
    if i  in IUD :
        
        print(f"IUD:{i}")
        a.append(i)


for i in answer:

    if i  in P2 :
        
        print(f"P2:{i}")
        b.append(i)

for i in answer:

    if i  in pill :
        print(f"pill:{i}")
        
        
        c.append(i)

for i in answer:

    if i  in pill :
        print(f"pull out:{i}")
        
        
        d.append(i)
for i in answer:

    if i  in pill :
        print(f"condom:{i}")
        
        
        e.append(i)
if len(answer) == 0:
    print(f'From our calculation : ')
    print('\nWe have seen you are eligible to use IUD \n')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_iud  )
        print('\nfor more infomation visit\n{https://www.webmd.com/sex/birth-control/iud-intrauterine-device}')
    elif x=='no' or x=='n':
        pass 
    print('\nWe have seen you are eligible to use p2 \n')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_p2  )
        print('\nfor more information visit\n{https://www.webmd.com/drugs/2/drug-165345/option-2-oral/details}')
    elif x=='no' or x=='n':
        pass 
    print('\nWe have seen you are eligible to use pill \n')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_pill )
        print('\nfor more infomation visit\n{www.your-life.com}')
    elif x=='no' or x=='n':
        pass
    print('\nWe have seen you are eligible to use pull out \n')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_pull_out )
        print('\nfor more infomation visit\n{www.your-life.com}')
    elif x=='no' or x=='n':
        pass
    print('\nWe have seen you are eligible to use condom \n')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_condom )
        print('\nfor more infomation visit\n{www.your-life.com}')
    elif x=='no' or x=='n':
        pass

print('\n\n\nfor more help seek medical advise')
    
per=len(a)/len(answer)*100
per2=len(b)/len(answer)*100
per3=len(c)/len(answer)*100
per4=len(d)/len(answer)*100
per5=len(e)/len(answer)*100
print(per,per2,per3,per4,per5)
print (answer)
if per < 50:
    print(f'From our calculation : \nWe have seen you are eligible to use IUD \n ')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_iud  )
        print('\nfor more infomation visit\n{https://www.webmd.com/sex/birth-control/iud-intrauterine-device}')
    elif x=='no' or x=='n':
        pass 

if per2 < 50:
    print(f'From our calculation: \nWe have seen you are eligible to use p2 \n ')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_p2  )
        print('\nfor more information visit\n{https://www.webmd.com/drugs/2/drug-165345/option-2-oral/details}')
    elif x=='no' or x=='n':
        pass 
if per3 < 50:
    print(f'From our calculation : \nWe have seen you are eligible to use pill \n ')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_pill )
        print('\nfor more infomation visit\n{www.your-life.com}')
    elif x=='no' or x=='n':
        pass 

if per4 < 50:
    print(f'From our calculation : \nWe have seen you are eligible to use pull out \n ')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_pull_out )
        print('\nfor more infomation visit\n{www.your-life.com}')
    elif x=='no' or x=='n':
        pass 
if per5 > 0:
    print('From our calculation: \nWe have seen you are eligible to use condom \n')
    x=(input("Would you like to know more of this method: Type yes(y) or no (n)"))
    if x=='yes' or x=='y':
        print(adv_condom )
        print('\nfor more infomation visit\n{www.your-life.com}')
    elif x=='no' or x=='n':
        pass
    print('\n\n\nfor more help seek medical advise')
print('\n\nfor more help seek medical advise')
# Out:
# Type yes(y) or no (n) from the following set of questions:
# [do you have  Heavy menses ]n
# [do you have  liver problem ]n
# [do you have  Blood Pressure ]n
# [do you have  cancer ]n
# [Would you wish to have a baby ]n
# [Would you wish to have a hormonal ]n
# [Would you want to be protected from  STD & HIV  infection]n
# []
# From our calculation :
#
# We have seen you are eligible to use IUD
#
# Would you like to know more of this method: Type yes(y) or no (n)y
# ['"IUD" stands for "intrauterine device." Shaped like a "T" and a bit bigger than a quarter, an IUD fits inside your uterus. It prevents pregnancy by stopping sperm from reaching and fertilizing eggs.']
#
# for more infomation visit
# {https://www.webmd.com/sex/birth-control/iud-intrauterine-device}
#
# We have seen you are eligible to use p2
#
# Would you like to know more of this method: Type yes(y) or no (n)y
# ...
